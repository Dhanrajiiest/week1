# %%
# Emoji Mood Responder

mood_dict = {
    "happy": ("😊", "Keep smiling and spread the joy!"),
    "sad": ("😢", "It's okay to feel sad. Tomorrow is a new day."),
    "angry": ("😠", "Take a deep breath. You’ve got this!"),
    "excited": ("🤩", "Your energy is contagious! Enjoy it!"),
    "tired": ("😴", "Get some rest. You deserve it!"),
    "confused": ("😕", "It’s okay to not have all the answers.")
}

user_mood = input("How are you feeling today? ").strip().lower()

if user_mood in mood_dict:
    emoji, message = mood_dict[user_mood]
    print(f"{emoji} {message}")
else
    print("🤔 I don't recognize that mood, but I hope you have a great day!")
# Out:
# How are you feeling today? sad
# 😢 It's okay to feel sad. Tomorrow is a new day.
